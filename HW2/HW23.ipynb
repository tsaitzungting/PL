# %%
import json

# %%
test = open('an0y3-o10vw.json',encoding="utf8")
Data = json.load(test)
type(Data)
# Out:
# dict

# %%
Data.items()
# Out:
# dict_items([('Games', [{'名次': '1', '遊戲名': '集合啦！動物森友會', '發行日': '2020年3月20日', '銷售量(萬)': '3938', '類型': '生活模擬', '中文': '是', '發行量': '任天堂企劃製作本部'}, {'名次': '2', '遊戲名': '寶可夢 晶燦鑽石／明亮珍珠', '發行日': '2021年11月19日', '銷售量(萬)': '1479', '類型': '角色扮演', '中文': '是', '發行量': 'ILCA（日语：）'}, {'名次': '3', '遊戲名': '寶可夢傳說 阿爾宙斯', '發行日': '2022年1月28日', '銷售量(萬)': '1264', '類型': '動作角色扮演', '中文': '是', '發行量': 'GAME FREAK'}, {'名次': '4', '遊戲名': '超級瑪利歐3D世界+狂怒世界', '發行日': '2021年2月12日', '銷售量(萬)': '943', '類型': '平台', '中文': '是', '發行量': '任天堂企劃製作本部'}, {'名次': '5', '遊戲名': '超級瑪利歐 3D收藏輯', '發行日': '2020年9月18日', '銷售量(萬)': '907', '類型': '平台', '中文': '否', '發行量': '任天堂企劃製作本部'}, {'名次': '6', '遊戲名': '魔物獵人 崛起', '發行日': '2021年3月26日', '銷售量(萬)': '770', '類型': '動作角色扮演', '中文': '是', '發行量': '卡普空'}, {'名次': '7', '遊戲名': '瑪利歐派對 超級巨星', '發行日': '2021年10月29日', '銷售量(萬)': '688', '類型': '聚會', '中文': '是', '發行量': 'NDcube'}, {'名次': '8', '遊戲名': 'Nintendo Switch 運動', '發行日': '2022年4月29日', '銷售量(萬)': '484', '類型': '體育', '中文': '是', '發行量': '任天堂企劃製作本部'}, {'名次': '9', '遊戲名': '星之卡比 探索發現', '發行日': '2022年3月25日', '銷售量(萬)': '453', '類型': '平台', '中文': '是', '發行量': 'HAL研究所'}, {'名次': '10', '遊戲名': '世界遊戲大全51', '發行日': '2020年6月5日', '銷售量(萬)': '422', '類型': '桌上、聚會', '中文': '是', '發行量': 'NDcube'}, {'名次': '11', '遊戲名': '薩爾達無雙 災厄啟示錄', '發行日': '2020年11月20日', '銷售量(萬)': '400', '類型': '砍殺', '中文': '是', '發行量': '光榮特庫摩'}, {'名次': '12', '遊戲名': '薩爾達傳說 禦天之劍 HD', '發行日': '2021年7月16日', '銷售量(萬)': '391', '類型': '動作冒險', '中文': '是', '發行量': '丹達羅斯媒體（英语：）'}, {'名次': '13', '遊戲名': '桃太郎電鐵～昭和 平成 令和也是基本款！～', '發行日': '2020年11月19日', '銷售量(萬)': '350', '類型': '棋盤', '中文': '否', '發行量': 'INFIGHT'}, {'名次': '14', '遊戲名': '紙片瑪利歐 摺紙國王', '發行日': '2020年7月17日', '銷售量(萬)': '334', '類型': '角色扮演', '中文': '是', '發行量': 'Intelligent Systems'}, {'名次': '15', '遊戲名': 'Among Us', '發行日': '2020年12月15日', '銷售量(萬)': '320', '類型': '聚會、生存', '中文': '是', '發行量': 'InnerSloth'}, {'名次': '16', '遊戲名': '密特羅德 生存恐懼', '發行日': '2021年10月8日', '銷售量(萬)': '290', '類型': '動作冒險', '中文': '是', '發行量': '水銀蒸氣'}, {'名次': '17', '遊戲名': 'New 寶可夢隨樂拍', '發行日': '2021年4月30日', '銷售量(萬)': '240', '類型': '動作、模擬', '中文': '是', '發行量': '萬代南夢宮工作室'}, {'名次': '18', '遊戲名': '瑪利歐高爾夫 超級衝衝衝', '發行日': '2021年6月25日', '銷售量(萬)': '235', '類型': '體育', '中文': '是', '發行量': 'Camelot Software Planning'}, {'名次': '19', '遊戲名': '皮克敏3 豪華版', '發行日': '2020年10月30日', '銷售量(萬)': '223', '類型': '即時戰略', '中文': '是', '發行量': '任天堂情報開發本部'}, {'名次': '20', '遊戲名': '瑪利歐激戰前鋒 戰鬥聯賽', '發行日': '2022年6月10日', '銷售量(萬)': '191', '類型': '體育', '中文': '是', '發行量': 'Next Level Games'}, {'名次': '21', '遊戲名': '寶可夢不可思議迷宮 救難隊DX（英语：）', '發行日': '2020年3月6日', '銷售量(萬)': '189', '類型': '隨機迷宮、角色扮演', '中文': '否', '發行量': 'Spike Chunsoft'}, {'名次': '22', '遊戲名': '迷托邦', '發行日': '2021年5月21日', '銷售量(萬)': '168', '類型': '角色扮演', '中文': '是', '發行量': '任天堂企劃製作本部'}, {'名次': '23', '遊戲名': '異度神劍 終極版', '發行日': '2020年5月29日', '銷售量(萬)': '168', '類型': '角色扮演', '中文': '是', '發行量': 'Monolith Soft'}, {'名次': '24', '遊戲名': '靈活腦學校 一起伸展大腦', '發行日': '2021年12月3日', '銷售量(萬)': '159', '類型': '教育', '中文': '是', '發行量': '任天堂企劃製作本部'}, {'名次': '25', '遊戲名': '瑪利歐賽車實況 家庭賽車場', '發行日': '2020年10月16日', '銷售量(萬)': '158', '類型': '競速、擴增實境', '中文': '是', '發行量': 'Velan Studios'}, {'名次': '26', '遊戲名': '分享同樂！瓦利歐製造', '發行日': '2021年9月10日', '銷售量(萬)': '127', '類型': '益智、動作', '中文': '是', '發行量': 'Intelligent Systems'}, {'名次': '27', '遊戲名': '附帶導航！一做就上手 第一次的遊戲程式設計', '發行日': '2021年6月11日', '銷售量(萬)': '106', '類型': '關卡編輯器', '中文': '是', '發行量': '任天堂企劃製作本部'}, {'名次': '28', '遊戲名': '火焰之纹章无双 风花雪月', '發行日': '2022年6月24日', '銷售量(萬)': '100', '類型': '砍殺', '中文': '是', '發行量': 'Team NINJA'}])])

# %%
temp = Data.get('Games')
temp
# Out:
# [{'名次': '1',
#   '遊戲名': '集合啦！動物森友會',
#   '發行日': '2020年3月20日',
#   '銷售量(萬)': '3938',
#   '類型': '生活模擬',
#   '中文': '是',
#   '發行量': '任天堂企劃製作本部'},
#  {'名次': '2',
#   '遊戲名': '寶可夢 晶燦鑽石／明亮珍珠',
#   '發行日': '2021年11月19日',
#   '銷售量(萬)': '1479',
#   '類型': '角色扮演',
#   '中文': '是',
#   '發行量': 'ILCA（日语：）'},
#  {'名次': '3',
#   '遊戲名': '寶可夢傳說 阿爾宙斯',
#   '發行日': '2022年1月28日',
#   '銷售量(萬)': '1264',
#   '類型': '動作角色扮演',
#   '中文': '是',
#   '發行量': 'GAME FREAK'},
#  {'名次': '4',
#   '遊戲名': '超級瑪利歐3D世界+狂怒世界',
#   '發行日': '2021年2月12日',
#   '銷售量(萬)': '943',
#   '類型': '平台',
#   '中文': '是',
#   '發行量': '任天堂企劃製作本部'},
#  {'名次': '5',
#   '遊戲名': '超級瑪利歐 3D收藏輯',
#   '發行日': '2020年9月18日',
#   '銷售量(萬)': '907',
#   '類型': '平台',
#   '中文': '否',
#   '發行量': '任天堂企劃製作本部'},
#  {'名次': '6',
#   '遊戲名': '魔物獵人 崛起',
#   '發行日': '2021年3月26日',
#   '銷售量(萬)': '770',
#   '類型': '動作角色扮演',
#   '中文': '是',
#   '發行量': '卡普空'},
#  {'名次': '7',
#   '遊戲名': '瑪利歐派對 超級巨星',
#   '發行日': '2021年10月29日',
#   '銷售量(萬)': '688',
#   '類型': '聚會',
#   '中文': '是',
#   '發行量': 'NDcube'},
#  {'名次': '8',
#   '遊戲名': 'Nintendo Switch 運動',
#   '發行日': '2022年4月29日',
#   '銷售量(萬)': '484',
#   '類型': '體育',
#   '中文': '是',
#   '發行量': '任天堂企劃製作本部'},
#  {'名次': '9',
#   '遊戲名': '星之卡比 探索發現',
#   '發行日': '2022年3月25日',
#   '銷售量(萬)': '453',
#   '類型': '平台',
#   '中文': '是',
#   '發行量': 'HAL研究所'},
#  {'名次': '10',
#   '遊戲名': '世界遊戲大全51',
#   '發行日': '2020年6月5日',
#   '銷售量(萬)': '422',
#   '類型': '桌上、聚會',
#   '中文': '是',
#   '發行量': 'NDcube'},
#  {'名次': '11',
#   '遊戲名': '薩爾達無雙 災厄啟示錄',
#   '發行日': '2020年11月20日',
#   '銷售量(萬)': '400',
#   '類型': '砍殺',
#   '中文': '是',
#   '發行量': '光榮特庫摩'},
#  {'名次': '12',
#   '遊戲名': '薩爾達傳說 禦天之劍 HD',
#   '發行日': '2021年7月16日',
#   '銷售量(萬)': '391',
#   '類型': '動作冒險',
#   '中文': '是',
#   '發行量': '丹達羅斯媒體（英语：）'},
#  {'名次': '13',
#   '遊戲名': '桃太郎電鐵～昭和 平成 令和也是基本款！～',
#   '發行日': '2020年11月19日',
#   '銷售量(萬)': '350',
#   '類型': '棋盤',
#   '中文': '否',
#   '發行量': 'INFIGHT'},
#  {'名次': '14',
#   '遊戲名': '紙片瑪利歐 摺紙國王',
#   '發行日': '2020年7月17日',
#   '銷售量(萬)': '334',
#   '類型': '角色扮演',
#   '中文': '是',
#   '發行量': 'Intelligent Systems'},
#  {'名次': '15',
#   '遊戲名': 'Among Us',
#   '發行日': '2020年12月15日',
#   '銷售量(萬)': '320',
#   '類型': '聚會、生存',
#   '中文': '是',
#   '發行量': 'InnerSloth'},
#  {'名次': '16',
#   '遊戲名': '密特羅德 生存恐懼',
#   '發行日': '2021年10月8日',
#   '銷售量(萬)': '290',
#   '類型': '動作冒險',
#   '中文': '是',
#   '發行量': '水銀蒸氣'},
#  {'名次': '17',
#   '遊戲名': 'New 寶可夢隨樂拍',
#   '發行日': '2021年4月30日',
#   '銷售量(萬)': '240',
#   '類型': '動作、模擬',
#   '中文': '是',
#   '發行量': '萬代南夢宮工作室'},
#  {'名次': '18',
#   '遊戲名': '瑪利歐高爾夫 超級衝衝衝',
#   '發行日': '2021年6月25日',
#   '銷售量(萬)': '235',
#   '類型': '體育',
#   '中文': '是',
#   '發行量': 'Camelot Software Planning'},
#  {'名次': '19',
#   '遊戲名': '皮克敏3 豪華版',
#   '發行日': '2020年10月30日',
#   '銷售量(萬)': '223',
#   '類型': '即時戰略',
#   '中文': '是',
#   '發行量': '任天堂情報開發本部'},
#  {'名次': '20',
#   '遊戲名': '瑪利歐激戰前鋒 戰鬥聯賽',
#   '發行日': '2022年6月10日',
#   '銷售量(萬)': '191',
#   '類型': '體育',
#   '中文': '是',
#   '發行量': 'Next Level Games'},
#  {'名次': '21',
#   '遊戲名': '寶可夢不可思議迷宮 救難隊DX（英语：）',
#   '發行日': '2020年3月6日',
#   '銷售量(萬)': '189',
#   '類型': '隨機迷宮、角色扮演',
#   '中文': '否',
#   '發行量': 'Spike Chunsoft'},
#  {'名次': '22',
#   '遊戲名': '迷托邦',
#   '發行日': '2021年5月21日',
#   '銷售量(萬)': '168',
#   '類型': '角色扮演',
#   '中文': '是',
#   '發行量': '任天堂企劃製作本部'},
#  {'名次': '23',
#   '遊戲名': '異度神劍 終極版',
#   '發行日': '2020年5月29日',
#   '銷售量(萬)': '168',
#   '類型': '角色扮演',
#   '中文': '是',
#   '發行量': 'Monolith Soft'},
#  {'名次': '24',
#   '遊戲名': '靈活腦學校 一起伸展大腦',
#   '發行日': '2021年12月3日',
#   '銷售量(萬)': '159',
#   '類型': '教育',
#   '中文': '是',
#   '發行量': '任天堂企劃製作本部'},
#  {'名次': '25',
#   '遊戲名': '瑪利歐賽車實況 家庭賽車場',
#   '發行日': '2020年10月16日',
#   '銷售量(萬)': '158',
#   '類型': '競速、擴增實境',
#   '中文': '是',
#   '發行量': 'Velan Studios'},
#  {'名次': '26',
#   '遊戲名': '分享同樂！瓦利歐製造',
#   '發行日': '2021年9月10日',
#   '銷售量(萬)': '127',
#   '類型': '益智、動作',
#   '中文': '是',
#   '發行量': 'Intelligent Systems'},
#  {'名次': '27',
#   '遊戲名': '附帶導航！一做就上手 第一次的遊戲程式設計',
#   '發行日': '2021年6月11日',
#   '銷售量(萬)': '106',
#   '類型': '關卡編輯器',
#   '中文': '是',
#   '發行量': '任天堂企劃製作本部'},
#  {'名次': '28',
#   '遊戲名': '火焰之纹章无双 风花雪月',
#   '發行日': '2022年6月24日',
#   '銷售量(萬)': '100',
#   '類型': '砍殺',
#   '中文': '是',
#   '發行量': 'Team NINJA'}]

# %%
#查詢遊戲資訊
ask = "集合啦！動物森友會"

# %%
for i in temp:
    if ask == i.get('遊戲名'):
        print(ask, '的名次是', i.get('名次'), '名，銷售量是', i.get('銷售量(萬)'),'萬')
# Out:
# 集合啦！動物森友會 的名次是 1 名，銷售量是 3938 萬

# %%
#排序銷售量
allage = []
for i in temp:
    allage.append(i.get('銷售量(萬)'))
allage
# Out:
# ['3938',
#  '1479',
#  '1264',
#  '943',
#  '907',
#  '770',
#  '688',
#  '484',
#  '453',
#  '422',
#  '400',
#  '391',
#  '350',
#  '334',
#  '320',
#  '290',
#  '240',
#  '235',
#  '223',
#  '191',
#  '189',
#  '168',
#  '168',
#  '159',
#  '158',
#  '127',
#  '106',
#  '100']

# %%
allage_enumerate = enumerate(allage, start = 1)

# %%
allage_enumerate_sorted = sorted(allage_enumerate, key = lambda s: s[1], reverse = True)
allage_enumerate_sorted
# Out:
# [(4, '943'),
#  (5, '907'),
#  (6, '770'),
#  (7, '688'),
#  (8, '484'),
#  (9, '453'),
#  (10, '422'),
#  (11, '400'),
#  (1, '3938'),
#  (12, '391'),
#  (13, '350'),
#  (14, '334'),
#  (15, '320'),
#  (16, '290'),
#  (17, '240'),
#  (18, '235'),
#  (19, '223'),
#  (20, '191'),
#  (21, '189'),
#  (22, '168'),
#  (23, '168'),
#  (24, '159'),
#  (25, '158'),
#  (2, '1479'),
#  (26, '127'),
#  (3, '1264'),
#  (27, '106'),
#  (28, '100')]

# %%
allage_enumerate_sorted[0][0]
# Out:
# 4

# %%
# 印出排序過後的遊戲資訊
for i in allage_enumerate_sorted:
    j = i[0] - 1
    print(temp[j].get('遊戲名'), '是第', temp[j].get('名次'), '名')
# Out:
# 超級瑪利歐3D世界+狂怒世界 是第 4 名
# 超級瑪利歐 3D收藏輯 是第 5 名
# 魔物獵人 崛起 是第 6 名
# 瑪利歐派對 超級巨星 是第 7 名
# Nintendo Switch 運動 是第 8 名
# 星之卡比 探索發現 是第 9 名
# 世界遊戲大全51 是第 10 名
# 薩爾達無雙 災厄啟示錄 是第 11 名
# 集合啦！動物森友會 是第 1 名
# 薩爾達傳說 禦天之劍 HD 是第 12 名
# 桃太郎電鐵～昭和 平成 令和也是基本款！～ 是第 13 名
# 紙片瑪利歐 摺紙國王 是第 14 名
# Among Us 是第 15 名
# 密特羅德 生存恐懼 是第 16 名
# New 寶可夢隨樂拍 是第 17 名
# 瑪利歐高爾夫 超級衝衝衝 是第 18 名
# 皮克敏3 豪華版 是第 19 名
# 瑪利歐激戰前鋒 戰鬥聯賽 是第 20 名
# 寶可夢不可思議迷宮 救難隊DX（英语：） 是第 21 名
# 迷托邦 是第 22 名
# 異度神劍 終極版 是第 23 名
# 靈活腦學校 一起伸展大腦 是第 24 名
# 瑪利歐賽車實況 家庭賽車場 是第 25 名
# 寶可夢 晶燦鑽石／明亮珍珠 是第 2 名
# 分享同樂！瓦利歐製造 是第 26 名
# 寶可夢傳說 阿爾宙斯 是第 3 名
# 附帶導航！一做就上手 第一次的遊戲程式設計 是第 27 名
# 火焰之纹章无双 风花雪月 是第 28 名
